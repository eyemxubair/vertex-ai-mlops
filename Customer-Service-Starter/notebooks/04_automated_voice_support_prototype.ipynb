# %% [markdown]
# # 04 – Automated Voice Support (Prototype)

# %%
from src.utils import simple_keywords_route

tests = [
    "I was charged twice this month.",
    "I want to cancel my internet plan.",
    "My internet is down since morning.",
    "I forgot my password and OTP doesn't arrive."
]
for u in tests:
    print(u, '->', simple_keywords_route(u))

# %% [markdown]
# ## (Optional) Wire Google Cloud STT/TTS (skeleton)
# Use `google-cloud-speech` and `google-cloud-texttospeech` to process audio.

# %%
# from google.cloud import speech, texttospeech
# def synthesize(text):
#     client = texttospeech.TextToSpeechClient()
#     ...
#     return 'reply.mp3'

# %% [markdown]
# ### Next steps
# - Replace rules with your deployed classifier endpoint
# - Add Dialogflow CX/telephony integration
# - Log interactions for continuous training
