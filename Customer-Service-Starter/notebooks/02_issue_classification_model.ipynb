# %% [markdown]
# # 02 – Issue Classification (Baseline + Vertex AI AutoML)

# %%
# Baseline TF-IDF + LinearSVC
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

train = pd.read_csv('train_split.csv')
val = pd.read_csv('val_split.csv')

clf = Pipeline([
    ('tfidf', TfidfVectorizer(ngram_range=(1,2), min_df=1))
    ,('svm', LinearSVC())
])
clf.fit(train['text'], train['label'])
preds = clf.predict(val['text'])
print(classification_report(val['label'], preds))

# %% [markdown]
# ## Vertex AI AutoML Text (skeleton)
# Upload CSV to GCS and run AutoML training; then deploy model for prediction.

# %%
# from google.cloud import aiplatform
# dataset = aiplatform.TextDataset.create(
#     display_name='cs_issue_ds',
#     gcs_source=['gs://<bucket>/complaints_train.csv'],
#     import_schema_uri=aiplatform.schema.dataset.ioformat.text.single_label_classification
# )
# job = aiplatform.AutoMLTextTrainingJob(
#     display_name='cs_issue_automl', prediction_type='classification', multi_label=False
# )
# model = job.run(dataset=dataset, model_display_name='cs_issue_model', budget_milli_node_hours=1000)
# endpoint = model.deploy()
