# %% [markdown]
# # 00 – Vertex AI Quickstart (Customer Service)
#
# Initializes your GCP project for: complaint classification, CSAT analysis, and voice support.
#
# **Prereqs**: `gcloud auth application-default login`, Vertex AI + Speech APIs enabled.

# %%
# !pip install -U google-cloud-aiplatform google-cloud-language google-cloud-speech google-cloud-texttospeech pandas scikit-learn matplotlib
import os
PROJECT_ID = os.getenv('PROJECT_ID','your-gcp-project-id')
REGION = os.getenv('REGION','us-central1')
print(PROJECT_ID, REGION)

# %%
from google.cloud import aiplatform

aiplatform.init(project=PROJECT_ID, location=REGION)
print('Vertex AI initialized.')
